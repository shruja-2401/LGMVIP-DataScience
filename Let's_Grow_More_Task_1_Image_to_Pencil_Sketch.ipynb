# %% [markdown]
# <a href="https://colab.research.google.com/github/shruja-2401/LGMVIP-DataScience/blob/main/Let's_Grow_More_Task_1_Image_to_Pencil_Sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
image = cv2.imread("/Car.jpeg")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1250 at 0x7F0EF8A9F3D0>

# %%
grey = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(grey)
# Out:
# <PIL.Image.Image image mode=L size=1000x1250 at 0x7F0EF71CBDD0>

# %%
invert = cv2.bitwise_not(grey)
cv2_imshow(invert)
# Out:
# <PIL.Image.Image image mode=L size=1000x1250 at 0x7F0EF8A9F210>

# %%
blur = cv2.GaussianBlur(invert, (21,21),0)
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=1000x1250 at 0x7F0EF8A35D50>

# %%
invertblur = cv2.bitwise_not(blur)
cv2_imshow(invertblur)
# Out:
# <PIL.Image.Image image mode=L size=1000x1250 at 0x7F0EF8A9F0D0>

# %%
sketch = cv2.divide(grey,invertblur,scale=255.0)
cv2_imshow(sketch)
cv2.imwrite("/Car.jpeg",sketch)
# Out:
# <PIL.Image.Image image mode=L size=1000x1250 at 0x7F0EF8A35950>
# True
